# %% [markdown]
# ## Module Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Import

# %%
df = pd.read_excel(r"T:\Data Field\DATAMITES CDA\INTERNSHIP FINAL PROJECT\Documents\automobile-insurance-company-complaint-rankings-beginning-2009-1 (1).xlsx")
pd.set_option('display.max.rows',1359)
pd.set_option('display.max.columns',11)
df
# Out:
#        NAIC                                       Company Name      Ratio  \
# 0     32786            Progressive Specialty Insurance Company     0.0000
# 1     19976                     Amica Mutual Insurance Company     0.0000
# 2     25453            Nationwide Insurance Company of America     0.0000
# 3     15024                 Preferred Mutual Insurance Company     0.0000
# 4     10052                   Chubb National Insurance Company     0.0000
# 5     43478          Utica National Insurance Company of Texas     0.0000
# 6     16233                 Erie Insurance Company of New York     0.0000
# 7     42919         Progressive Northwestern Insurance Company     0.0000
# 8     34460                        Maidstone Insurance Company     0.0000
# 9     36145      Travelers Personal Security Insurance Company     0.0000
# 10    25712                         Esurance Insurance Company     0.0000
# 11    29742                 Integon National Insurance Company     0.0000
# ...

# %% [markdown]
# ## Statistical Measures

# %%
df.describe()
# Out:
#                NAIC        Ratio  Upheld Complaints  \
# count   1358.000000  1358.000000        1358.000000
# mean   23936.145803     1.889557           3.104566
# std     9541.622447    38.291439          12.526851
# min    10022.000000     0.000000           0.000000
# 25%    16105.500000     0.000000           0.000000
# 50%    23450.000000     0.016400           1.000000
# 75%    29939.000000     0.106400           2.000000
# max    43974.000000  1364.877200         265.000000
#
#        Question of Fact Complaints  Not Upheld Complaints  Total Complaints  \
# count                  1358.000000            1358.000000       1358.000000
# mean                      8.449190              14.896171         26.449926
# std                      33.353889              43.687174         84.382503
# min                       0.000000               0.000000          0.000000
# 25%                       0.000000               1.000000          2.000000
# ...

# %%
df.median()
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_15500\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# NAIC                              23450.0000
# Ratio                                 0.0164
# Upheld Complaints                     1.0000
# Question of Fact Complaints           1.0000
# Not Upheld Complaints                 3.0000
# Total Complaints                      6.0000
# Premiums Written (in Millions)       11.0040
# Rank                                 85.0000
# Filing Year                        2012.0000
# dtype: float64

# %% [markdown]
# ## Finding Correlation between features using Pearson Correlation Coefficient

# %%
import seaborn as sns

df_numeric = df.select_dtypes(include=['float64', 'int64'])

# Calculate Correlation Matrix
corr = df_numeric.corr()

# Plot correlation matrix
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot= True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Auto_Insurance_Data')
plt.show()
